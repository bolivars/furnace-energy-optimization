# %% [markdown]
# ****
# ## **MODELO DE ELEMENTOS FINITOS QUE SIMULA EL PROCESO DE CALENTAMIENTO DE UNA PALANQUILLA A SU PASO POR UN HORNO DE INDUCCIÓN**
# ****
#
# **Autor**: Sergio Bolívar Gómez.
#
# **Fecha**: 10 de abril de 2023.

# %% [markdown]
# En primer lugar, cargamos las librerías que utilizaremos tanto para realizar la simulación como para representar gráficamente los resultados obtenidos.

# %%
import os # importamos la librería os para poder interactuar con el sistema operativo
import pandas as pd # importamos la librería pandas para manejar datos (uso de DataFrames)
import numpy as np # importamos la librería numpy para hacer cálculos numéricos
import matplotlib.pyplot as plt # importamos la librería pyplot para representar gráficamente los resultados
import time # importamos la librería time para formatear el tiempo transcurrido

from ansys.mapdl.core import launch_mapdl # importamos la función launch_mapdl del módulo ansys.mapdl.core para conectarnos a ANSYS APDL

# %% [markdown]
# Una vez importadas las librerías necesarias, definimos una serie de funciones que nos van a facilitar la lectura de los datos. Sacando estas funciones del propio código ganamos modularidad, de manera que si los formatos proporcionados por GSW son algo complejos, podemos modificar estas funciones para adecuarlas a su lectura.

# %%
def load_case_studies_data(filename):
    """
    Carga los datos sobre los casos de estudio desde un CSV con las siguiente columnas:
    tiempo, avance, IND_1, IND_2, IND_3, IND_4
    
    Parametros:
    ----------
    filename (str): nombre del CSV que contiene los datos sobre los casos de estudio
    
    Output:
    ------
    data (pandas.DataFrame): un pandas DataFrame que contiene los datos
    
    """
    data = pd.read_csv(filename, header=0, skipinitialspace=True)
    return data


def load_material_properties(filename):
    """
    Carga los datos de propiedades de material desde un CSV con las siguientes columnas:
    conductividad, calor_especifico, densidad, coef_conv_air_acero

    Parametros:
    ----------
    filename (str): nombre del archivo csv que contiene los datos de las propiedades del material

    Returns
    -------
    data (pandas.DataFrame): un pandas DataFrame que contiene los datos

    """
    data = pd.read_csv(filename, header=0, skipinitialspace=True)
    return data


def load_boundary_conditions(filename):
    """
    Carga los datos sobre las condiciones de contorno desde un CSV con las siguientes columnas:
    temperatura_inicial, temperatura_aire

    Parametros:
    ----------
    filename (str): nombre del archivo csv que contiene los datos de las condiciones de contorno

    Returns
    -------
    data (pandas.DataFrame): un pandas DataFrame que contiene los datos

    """
    data = pd.read_csv(filename, header=0, skipinitialspace=True)
    return data

# %%
mapdl = launch_mapdl(nproc=10) # lanzamos una instancia de MAPDL y la asignamos a la variable mapdl

# %% [markdown]
# Elaboramos una lista con todas los identificadores de todas las palanquillas...

# %%
directory = f"C:\\Users\\bolivars\\Desktop\\JAE\\CODIGO\\CODIGO\\inputs-APDL\\Parametros_casos_estudio"

casos_estudio = []

for filename in os.listdir(directory):
    if filename.startswith("caso_estudio_palanquilla_") and filename.endswith(".csv"):
        number = filename.split("_")[-1].split(".")[0]
        casos_estudio.append(number)

casos_estudio.sort()

# %%
print("El número de casos de estudio analizados son", len(casos_estudio))
# Out:
# El número de casos de estudio analizados son 159

# %% [markdown]
# Comienza la simulación...

# %%
start_time_simul = time.time()

total_advance = 0 # avance de la palanquilla (esta variable no está definida en el código original, REVISAR)

dir_path = f"C:\\Users\\bolivars\\Desktop\\JAE\\CODIGO\\CODIGO\\inputs-APDL" # path al directorio de trabajo base

os.chdir(dir_path + "\Caso_0")

mapdl.parsav("SCALAR", 'paramentros_caso') # escribe los parámetros en un fichero

mapdl.config("NRES", 30000) # aumentamos el número máximo de substeps

for case_id in casos_estudio:

    print(75*"=")
    print(13*" ","COMIENZA LA SIMULACIÓN - PALANQUILLA",case_id)
    print(75*"=")

    start_time_case_study = time.time()

    # Cambiamos el directorio de trabajo al del caso 0, que contiene el estado incial para el análisis
    os.chdir(dir_path + "\Caso_0")
    mapdl.cwd(dir_path + "\Caso_0")

    mapdl.resume("estado_inicial_2_analisis", "db") # recupera la base de datos desde el archivo proporcionado
    mapdl.parres("NEW", "paramentros_caso") # lee los parámetros desde el archivo que le pasamos 
    mapdl.parsav("SCALAR", "paramentros_caso") # escribe los parámetros en un fichero

    # Desactivamos los pop-ups (para poder generar varios casos en serie)
    mapdl.keyw("PR_SGVOF", 1)
    mapdl.run("/NERR,5,10000, ,0,1000")
    
    mapdl.prep7() # entramos en el preproceso

    # Activamos la numeración en pantalla de puntos, líneas...
    mapdl.pnum("KP",1)
    mapdl.pnum("LINE",1)
    mapdl.pnum("AREA",1)
    mapdl.pnum("VOLU",1)
    mapdl.pnum("NODE",0)

    # Variables de la simulación (en principio son fijas, pero quizá también puedan leerse desde algún fichero)
    num_steps = 200 # para leer los ficheros de texto en orden
    influence = 1.1 # influencia del inductor
    sep_inductors = 0.5 # separación entre los inductores
    constant_loss = 50000 # a ajustar (está puesta a ojo, REVISAR)
    time_init_step = 0 # cuando hay varios casos, para que el tiempo inicial no se inferior al último del cálculo anterior

    # Cambiamos el directorio de trabajo al lugar donde se almacenan los parámetros fijos del modelo
    os.chdir(dir_path + "\Parametros_fijos_modelo")
    mapdl.cwd(dir_path + "\Parametros_fijos_modelo")

    mat_prop = load_material_properties("Propiedades_material.txt") # leemos las propiedades del material

    # Propiedades del material
    conductivity = mat_prop.loc[0,"conductividad"] # conductividad en W/(m·K)
    specific_heat = mat_prop.loc[0,"calor_especifico"] # calor específico en J/(kg·K)
    density = mat_prop.loc[0,"densidad"] # densidad en kg/m^3 
    conv_coef = mat_prop.loc[0,"coef_conv_air_acero"] # coeficiente de convección acero-aire (W/(m^2·K))

    # Geometría de la placa
    e = 0.14   # alto (m)
    b = 0.14   # ancho (m)
    a = 19.5   # largo (m)

    # Tamaño de los elementos de la malla
    elem_mesh_size = 0.02

    #############################
    ##### DEFINIR ELEMENTOS #####
    #############################

    mapdl.et(1, "SOLID70") # elemento 3D (3-D thermal conduction capability)

    #################################################
    ##### DEFINIR PROPIEDADES DE LOS MATERIALES #####
    #################################################

    mapdl.mptemp()                           # borra tabla de temperaturas
    mapdl.mptemp(1,1.0000000E+03)            # creamos una nueva tabla de temperaturas con identificador 1 y temperatura inicial de 1000 K
    mapdl.mpdata("DENS", 1, 1, density)      # añadimos datos a la tabla de propiedades del material: densidad
    mapdl.mptemp()                           # borra tabla de temperaturas
    mapdl.mptemp(1,1.0000000E+03)            # creamos una nueva tabla de temperaturas con identificador 1 y temperatura inicial de 1000 K
    mapdl.mpdata("KXX", 1, 1, conductivity)  # añadimos datos a la tabla de propiedades del material: conductividad térmica
    mapdl.mptemp(1,1.0000000E+00)               
    mapdl.mpdata("C", 1, 1, specific_heat)   # añadimos datos a la tabla de propiedades del material: calor específico

    ###############################################
    ##### DEFINIR LA GEOMETRÍA DEL COMPONENTE #####
    ###############################################

    mapdl.block(0, -a, 0, b, 0, e) # volumen que representa la palanquilla
    mapdl.view(1, 1, 2, 3) # ver en perspectiva
    mapdl.angle(1)
    mapdl.replot("FAST")

    ##########################################
    ##### DEFINIR MALLADO DEL COMPONENTE #####
    ##########################################
    
    mapdl.esize(elem_mesh_size, 5) # establecemos el tamaño de los elementos (segundo parámetro?)
    mapdl.mshape(0, "3D")
    mapdl.mshkey(1)

    mapdl.cm('_Y', 'VOLU') # creamos componente
    mapdl.vsel('', '', '', 1)
    mapdl.cm('_Y1', 'VOLU') # creamos componente
    mapdl.chkmsh('VOLU')
    mapdl.cmsel('S', '_Y')

    mapdl.vmesh('_Y1') # hacemos el mesh (genera nodos y elementos)

    # Eliminamos los componentes creados previamente
    mapdl.cmdele('_Y')
    mapdl.cmdele('_Y1')

    #########################
    ##### DEFINIR CASOS #####
    #########################

    mapdl.cswpla(12,0,0,0) # creamos un sistema local de coordenadas en el origen del WP

    #########################
    ###### CARGAR DATOS #####
    #########################

    # Importamos el tren de cargas
    os.chdir(dir_path + "\Parametros_casos_estudio")
    mapdl.cwd(dir_path + "\Parametros_casos_estudio")

    base_load_name = "caso_estudio_palanquilla_"
    current_case_study = base_load_name + case_id + ".csv"

    loads_current_case = load_case_studies_data(current_case_study) # cargamos el tren de cargas correspondiente al caso de estudio actual

    # Importamos las condiciones de contorno de temperaturas
    base_bound_cond_name = "cond_contorno_palanquilla_"
    current_case_study_bound_cond = base_bound_cond_name + case_id + ".csv"

    bound_cond_current_case = load_boundary_conditions(current_case_study_bound_cond) # cargamos las temperaturas de contorno correspondientes al caso actual

    temp_init = bound_cond_current_case.loc[0,"temperatura_inicial"] # temperatura inicial de la barra
    air_temp = bound_cond_current_case.loc[0,"temperatura_aire"] # temperatura del aire circundante

    ######################
    ###### SOLUCION ######
    ######################

    # ----- Primer LoadStep: fijar las condiciones iniciales -----

    mapdl.csys(12) # activamos el sistema de coordenadas que hemos definido anteriormente

    mapdl.nsel('S', 'LOC', 'X', 0.001, -0.001)	    # seleccionamos los nodos en la zona X=0
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)	# imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.nsel('S', 'LOC', 'Y', 0.001, -0.001)	    # seleccionamos los nodos en la zona Y=0
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)	# imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.nsel('S', 'LOC', 'Z', 0.001, -0.001)	    # seleccionamos los nodos en la zona Z=0
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)	# imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.nsel('S', 'LOC', 'X', a+0.001, a-0.001)	# seleccionamos los nodos en la zona X=a
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)   # imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.nsel('S', 'LOC', 'Y', b+0.001, b-0.001)	# seleccionamos los nodos en la zona Y=b
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)	# imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.nsel('S', 'LOC', 'Z', e+0.001, e-0.001)	# seleccionamos los nodos en la zona Z=e
    mapdl.sf('ALL', 'CONV', conv_coef, temp_init)	# imponemos una convección en los nodos seleccionados
    mapdl.allsel()

    mapdl.antype("TRANS")	# transitorio
    mapdl.timint('OFF')	    # se convierte en estacionario
    mapdl.time(0.003)	    # tiempo muy pequeño para resolver el estacionario
    mapdl.autots('ON')      # activamos el ajuste automático de substeps
    mapdl.finish()	        # cierre del resolvedor
    mapdl.run("/SOLU")
    mapdl.solve()

    # ----- Segundo LoadStep: fijar las condiciones del ciclo -----

    mapdl.antype("TRANS")     # análisis transitorio
    mapdl.kbc(0)              # aplicamos cargas RAMPPED
    mapdl.timint("ON")        # transitorio

    mapdl.cswpla(11,0,0,0)  # creamos un sistema local de coordenadas en el origen del WP. Número 11; en cilíndricas (1)
    mapdl.csys(11)          # activamos el sistema de coordenadas previamente definido

    # Comenzamos a recorrer los steps de la simulación
    for k in range(num_steps):

        start_time_step = time.time()

        mapdl.time(time_init_step+loads_current_case.loc[k,"tiempo"]) # tiempo del transitorio en segundos
        mapdl.autots('ON') # activamos el ajuste automático de substeps
        mapdl.outres("ALL", "ALL")

        mapdl.cswpla(11,0,0,0) # creamos un sistema local de coordenadas en el origen del WP. Número 11; en cilíndricas (1)
        mapdl.csys(11)         # activamos el sistema de coordenadas previamente definido

        mapdl.sfdele('ALL', 'ALL')	# eliminamos todas las posibles cargas previemente aplicadas
        mapdl.bfdele('ALL', 'ALL')	# eliminamos todas las posibles cargas previemente aplicadas sobre nodos
        mapdl.sfadele('ALL', 'ALL') # eliminamos todas las posibles cargas previamente aplicadas sobre áreas

        ##### GRUPO DE INDUCTORES 1 (hay tres inductores, del 1-3) #####
        for i in range(3):
            mapdl.nsel('S', 'LOC', 'X', 0 + i * (sep_inductors + influence) + 0.7, influence + i * (sep_inductors + influence) + 0.7)
            mapdl.nsel('R', 'LOC', 'Y', 0.001, b-0.001)
            mapdl.nsel('R', 'LOC', 'Z', 0.001, e-0.001)
            mapdl.bf('ALL', 'HGEN', loads_current_case.loc[k,"IND_1"]*constant_loss)
            mapdl.allsel()

        ##### GRUPO DE INDUCTORES 2 (hay tres inductores, del 4-6) #####
        for i in range(3,6):
            mapdl.nsel('S', 'LOC', 'X', 0 + i * (sep_inductors + influence) + 0.7, influence + i * (sep_inductors + influence) + 0.7)
            mapdl.nsel('R', 'LOC', 'Y', 0.001, b-0.001)
            mapdl.nsel('R', 'LOC', 'Z', 0.001, e-0.001)
            mapdl.bf('ALL', 'HGEN', loads_current_case.loc[k,"IND_2"]*constant_loss)
            mapdl.allsel()

        ##### GRUPO DE INDUCTORES 3 (hay tres inductores, del 7-9) #####
        for i in range(6,9):
            mapdl.nsel('S', 'LOC', 'X', 0 + i * (sep_inductors + influence) + 0.7, influence + i * (sep_inductors + influence) + 0.7)
            mapdl.nsel('R', 'LOC', 'Y', 0.001, b-0.001)
            mapdl.nsel('R', 'LOC', 'Z', 0.001, e-0.001)
            mapdl.bf('ALL', 'HGEN', loads_current_case.loc[k,"IND_3"]*constant_loss)
            mapdl.allsel()
        
        ##### GRUPO DE INDUCTORES 4 (hay tres inductores, del 10-12) #####
        for i in range(9,12):
            mapdl.nsel('S', 'LOC', 'X', 0 + i * (sep_inductors + influence) + 0.7, influence + i * (sep_inductors + influence) + 0.7)
            mapdl.nsel('R', 'LOC', 'Y', 0.001, b-0.001)
            mapdl.nsel('R', 'LOC', 'Z', 0.001, e-0.001)
            mapdl.bf('ALL', 'HGEN', loads_current_case.loc[k,"IND_4"]*constant_loss)
            mapdl.allsel()

        #### DEFINIR LAS CARGAS GENERADAS POR CONVECCIÓN CON EL AIRE ####
        mapdl.nsel('S', 'LOC', 'X', 0.001 - total_advance, -0.001 + total_advance) # seleccionamos los nodos en la zona X=0
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()  

        mapdl.nsel('S', 'LOC', 'Y', 0.001, -0.001) # seleccionamos los nodos en la zona Y=0
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()  

        mapdl.nsel('S', 'LOC', 'Z', 0.001, -0.001)  # seleccionamos los nodos en la zona Z=0
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()  

        mapdl.nsel('S', 'LOC', 'X', -a+0.001-total_advance, -a-0.001+total_advance) # seleccionamos los nodos en la zona X=-a
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()  

        mapdl.nsel('S', 'LOC', 'Y', b+0.001, b-0.001) # seleccionamos los nodos en la zona Y=b
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()  

        mapdl.nsel('S', 'LOC', 'Z', e+0.001, e-0.001) # seleccionamos los nodos en la zona Z=e
        mapdl.sf('ALL', 'CONV', conv_coef, air_temp) # imponemos una convección en los nodos seleccionados
        mapdl.allsel()

        mapdl.solve()

        total_advance += loads_current_case.loc[k,"avance"] # distancia del nuevo sistema de referencia a la posición original

        mapdl.wpoffs(-loads_current_case.loc[k,"avance"]) # avance del WP

        finish_time_step = time.time() 
        print(" -> El step", k+1, " se ha completado correctamente en", time.strftime("%Hh%Mm%Ss", time.gmtime(finish_time_step-start_time_step)), "(", num_steps-k-1, "restantes )")

    mapdl.finish()

    mapdl.wpoffs(+total_advance) # volver el sistema de referencia a 0

    time_init_step += loads_current_case.loc[k,"avance"] # hacer que el siguiente caso continue con el tiempo siguiente

    # Obtenemos resultados relativos a la simulación
    os.chdir(dir_path + "\Resultados")
    mapdl.cwd(dir_path + "\Resultados")

    mapdl.post1() # entramos en el post-proceso

    # Plot de la temperatura en cada punto de la palanquilla
    # mapdl.show("PNG")
    # mapdl.run("PLNSOL,TEMP,,0,")

    mapdl.path('Path_1', 2, 30, 199) # he cambiado 50 por 100
    mapdl.ppath(1, 0, 0, 0.14, 0.07, 11)
    mapdl.ppath(2, 0, -19.5, 0.14, 0.07, 11)  # generar un path a lo largo de la mitad de la cara superior

    mapdl.pdef('', 'TEMP', '', 'NOAVG')
    mapdl.pbc('PATH', '', 0) 

    # ESCRIBIR LOS RESULTADOS EN UN FICHERO DE TEXTO

    # Formateamos la escritura
    nsigfig = 10
    mapdl.header("OFF", "OFF", "OFF", "OFF", "OFF", "OFF")
    mapdl.format("", "E", nsigfig + 9, nsigfig)
    mapdl.page(1e9, "", -1, 240)

    # Sacamos una tabla con los datos del path (posición y temperatura)
    results_to_write = mapdl.prpath('TEMP')  # IMPORTANTE: esta instrucción siempre después del formateo!

    current_case_study_results = "resultados_caso_estudio_palanquilla_" + case_id + ".csv" # fichero en el que se escriben los resultados

    results_in_array = np.genfromtxt(results_to_write.splitlines()[1:]) # obtenemos los resultados numéricos a partir del TXT
    results_in_df = pd.DataFrame(results_in_array, columns=['posicion', 'temperatura']) # guardamos los resultados en un DataFrame
    results_in_df.to_csv(current_case_study_results,sep=',', header = True, index=False) # guardar los resultados en un TXT

    # Representación gráfica
    plt.plot(results_in_df["posicion"], results_in_df["temperatura"], color = "r")
    plt.xlabel('Position (m)')
    plt.ylabel('Temperature (ºC)')
    plt.title("STEEL BILLET " + case_id)
    image_name = "plots-case-studies/plot_caso_estudio_palanquilla_" + case_id + ".png"
    plt.savefig(image_name)
    plt.clf()

    # Tiempos de ejecución del caso de estudio
    finish_time_case_study = time.time()
    print("\n Se ha completado la simulación del caso de estudio", case_id)
    print(" El tiempo empleado han sido", time.strftime("%Hh%Mm%Ss", time.gmtime(finish_time_case_study-start_time_case_study)))
    print("")
# Tiempos de ejecución de la simulación total
finish_time_simul = time.time()
print(75*"=")
print("El tiempo empleado para toda la simulación han sido", time.strftime("%Hh%Mm%Ss", time.gmtime(finish_time_simul-start_time_simul)))
print(75*"=")
# Out:
# ===========================================================================
#               COMIENZA LA SIMULACIÓN - PALANQUILLA 6211285
# ===========================================================================
#  -> El step 1  se ha completado correctamente en 00h00m04s ( 199 restantes )
#  -> El step 2  se ha completado correctamente en 00h00m01s ( 198 restantes )
#  -> El step 3  se ha completado correctamente en 00h00m02s ( 197 restantes )
#  -> El step 4  se ha completado correctamente en 00h00m02s ( 196 restantes )
#  -> El step 5  se ha completado correctamente en 00h00m01s ( 195 restantes )
#  -> El step 6  se ha completado correctamente en 00h00m02s ( 194 restantes )
#  -> El step 7  se ha completado correctamente en 00h00m03s ( 193 restantes )
#  -> El step 8  se ha completado correctamente en 00h00m01s ( 192 restantes )
#  -> El step 9  se ha completado correctamente en 00h00m01s ( 191 restantes )
#  -> El step 10  se ha completado correctamente en 00h00m01s ( 190 restantes )
#  -> El step 11  se ha completado correctamente en 00h00m01s ( 189 restantes )
#  -> El step 12  se ha completado correctamente en 00h00m01s ( 188 restantes )
#  -> El step 13  se ha completado correctamente en 00h00m01s ( 187 restantes )
#  -> El step 14  se ha completado correctamente en 00h00m01s ( 186 restantes )
#  -> El step 15  se ha completado correctamente en 00h00m01s ( 185 restantes )
#  -> El step 16  se ha completado correctamente en 00h00m01s ( 184 restantes )
#  -> El step 17  se ha completado correctamente en 00h00m01s ( 183 restantes )
#  -> El step 18  se ha completado correctamente en 00h00m02s ( 182 restantes )
#  -> El step 19  se ha completado correctamente en 00h00m01s ( 181 restantes )
#  -> El step 20  se ha completado correctamente en 00h00m02s ( 180 restantes )
#  -> El step 21  se ha completado correctamente en 00h00m01s ( 179 restantes )
#  -> El step 22  se ha completado correctamente en 00h00m01s ( 178 restantes )
#  -> El step 23  se ha completado correctamente en 00h00m01s ( 177 restantes )
#  -> El step 24  se ha completado correctamente en 00h00m01s ( 176 restantes )
#  -> El step 25  se ha completado correctamente en 00h00m01s ( 175 restantes )
#  -> El step 26  se ha completado correctamente en 00h00m01s ( 174 restantes )
#  -> El step 27  se ha completado correctamente en 00h00m01s ( 173 restantes )
#  -> El step 28  se ha completado correctamente en 00h00m02s ( 172 restantes )
#  -> El step 29  se ha completado correctamente en 00h00m02s ( 171 restantes )
#  -> El step 30  se ha completado correctamente en 00h00m01s ( 170 restantes )
#  -> El step 31  se ha completado correctamente en 00h00m02s ( 169 restantes )
#  -> El step 32  se ha completado correctamente en 00h00m01s ( 168 restantes )
#  -> El step 33  se ha completado correctamente en 00h00m01s ( 167 restantes )
#  -> El step 34  se ha completado correctamente en 00h00m01s ( 166 restantes )
#  -> El step 35  se ha completado correctamente en 00h00m01s ( 165 restantes )
#  -> El step 36  se ha completado correctamente en 00h00m01s ( 164 restantes )
#  -> El step 37  se ha completado correctamente en 00h00m02s ( 163 restantes )
#  -> El step 38  se ha completado correctamente en 00h00m01s ( 162 restantes )
#  -> El step 39  se ha completado correctamente en 00h00m01s ( 161 restantes )
#  -> El step 40  se ha completado correctamente en 00h00m02s ( 160 restantes )
#  -> El step 41  se ha completado correctamente en 00h00m01s ( 159 restantes )
#  -> El step 42  se ha completado correctamente en 00h00m01s ( 158 restantes )
#  -> El step 43  se ha completado correctamente en 00h00m01s ( 157 restantes )
#  -> El step 44  se ha completado correctamente en 00h00m02s ( 156 restantes )
#  -> El step 45  se ha completado correctamente en 00h00m02s ( 155 restantes )
#  -> El step 46  se ha completado correctamente en 00h00m01s ( 154 restantes )
#  -> El step 47  se ha completado correctamente en 00h00m02s ( 153 restantes )
#  -> El step 48  se ha completado correctamente en 00h00m01s ( 152 restantes )
#  -> El step 49  se ha completado correctamente en 00h00m01s ( 151 restantes )
#  -> El step 50  se ha completado correctamente en 00h00m02s ( 150 restantes )
#  -> El step 51  se ha completado correctamente en 00h00m01s ( 149 restantes )
#  -> El step 52  se ha completado correctamente en 00h00m01s ( 148 restantes )
#  -> El step 53  se ha completado correctamente en 00h00m01s ( 147 restantes )
#  -> El step 54  se ha completado correctamente en 00h00m02s ( 146 restantes )
#  -> El step 55  se ha completado correctamente en 00h00m01s ( 145 restantes )
#  -> El step 56  se ha completado correctamente en 00h00m01s ( 144 restantes )
#  -> El step 57  se ha completado correctamente en 00h00m02s ( 143 restantes )
#  -> El step 58  se ha completado correctamente en 00h00m02s ( 142 restantes )
#  -> El step 59  se ha completado correctamente en 00h00m01s ( 141 restantes )
#  -> El step 60  se ha completado correctamente en 00h00m02s ( 140 restantes )
#  -> El step 61  se ha completado correctamente en 00h00m02s ( 139 restantes )
#  -> El step 62  se ha completado correctamente en 00h00m02s ( 138 restantes )
#  -> El step 63  se ha completado correctamente en 00h00m01s ( 137 restantes )
#  -> El step 64  se ha completado correctamente en 00h00m02s ( 136 restantes )
#  -> El step 65  se ha completado correctamente en 00h00m02s ( 135 restantes )
#  -> El step 66  se ha completado correctamente en 00h00m01s ( 134 restantes )
#  -> El step 67  se ha completado correctamente en 00h00m02s ( 133 restantes )
#  -> El step 68  se ha completado correctamente en 00h00m02s ( 132 restantes )
#  -> El step 69  se ha completado correctamente en 00h00m02s ( 131 restantes )
#  -> El step 70  se ha completado correctamente en 00h00m01s ( 130 restantes )
#  -> El step 71  se ha completado correctamente en 00h00m02s ( 129 restantes )
#  -> El step 72  se ha completado correctamente en 00h00m02s ( 128 restantes )
#  -> El step 73  se ha completado correctamente en 00h00m02s ( 127 restantes )
#  -> El step 74  se ha completado correctamente en 00h00m02s ( 126 restantes )
#  -> El step 75  se ha completado correctamente en 00h00m01s ( 125 restantes )
#  -> El step 76  se ha completado correctamente en 00h00m02s ( 124 restantes )
#  -> El step 77  se ha completado correctamente en 00h00m01s ( 123 restantes )
#  -> El step 78  se ha completado correctamente en 00h00m02s ( 122 restantes )
#  -> El step 79  se ha completado correctamente en 00h00m01s ( 121 restantes )
#  -> El step 80  se ha completado correctamente en 00h00m01s ( 120 restantes )
#  -> El step 81  se ha completado correctamente en 00h00m01s ( 119 restantes )
#  -> El step 82  se ha completado correctamente en 00h00m01s ( 118 restantes )
#  -> El step 83  se ha completado correctamente en 00h00m02s ( 117 restantes )
#  -> El step 84  se ha completado correctamente en 00h00m02s ( 116 restantes )
#  -> El step 85  se ha completado correctamente en 00h00m01s ( 115 restantes )
#  -> El step 86  se ha completado correctamente en 00h00m02s ( 114 restantes )
#  -> El step 87  se ha completado correctamente en 00h00m01s ( 113 restantes )
#  -> El step 88  se ha completado correctamente en 00h00m01s ( 112 restantes )
#  -> El step 89  se ha completado correctamente en 00h00m01s ( 111 restantes )
#  -> El step 90  se ha completado correctamente en 00h00m01s ( 110 restantes )
#  -> El step 91  se ha completado correctamente en 00h00m01s ( 109 restantes )
#  -> El step 92  se ha completado correctamente en 00h00m01s ( 108 restantes )
#  -> El step 93  se ha completado correctamente en 00h00m01s ( 107 restantes )
#  -> El step 94  se ha completado correctamente en 00h00m02s ( 106 restantes )
#  -> El step 95  se ha completado correctamente en 00h00m01s ( 105 restantes )
#  -> El step 96  se ha completado correctamente en 00h00m02s ( 104 restantes )
#  -> El step 97  se ha completado correctamente en 00h00m01s ( 103 restantes )
#  -> El step 98  se ha completado correctamente en 00h00m01s ( 102 restantes )
#  -> El step 99  se ha completado correctamente en 00h00m01s ( 101 restantes )
#  -> El step 100  se ha completado correctamente en 00h00m01s ( 100 restantes )
#  -> El step 101  se ha completado correctamente en 00h00m01s ( 99 restantes )
#  -> El step 102  se ha completado correctamente en 00h00m01s ( 98 restantes )
#  -> El step 103  se ha completado correctamente en 00h00m01s ( 97 restantes )
#  -> El step 104  se ha completado correctamente en 00h00m01s ( 96 restantes )
#  -> El step 105  se ha completado correctamente en 00h00m01s ( 95 restantes )
#  -> El step 106  se ha completado correctamente en 00h00m01s ( 94 restantes )
#  -> El step 107  se ha completado correctamente en 00h00m01s ( 93 restantes )
#  -> El step 108  se ha completado correctamente en 00h00m01s ( 92 restantes )
#  -> El step 109  se ha completado correctamente en 00h00m01s ( 91 restantes )
#  -> El step 110  se ha completado correctamente en 00h00m01s ( 90 restantes )
#  -> El step 111  se ha completado correctamente en 00h00m03s ( 89 restantes )
#  -> El step 112  se ha completado correctamente en 00h00m02s ( 88 restantes )
#  -> El step 113  se ha completado correctamente en 00h00m01s ( 87 restantes )
#  -> El step 114  se ha completado correctamente en 00h00m02s ( 86 restantes )
#  -> El step 115  se ha completado correctamente en 00h00m01s ( 85 restantes )
#  -> El step 116  se ha completado correctamente en 00h00m01s ( 84 restantes )
#  -> El step 117  se ha completado correctamente en 00h00m01s ( 83 restantes )
#  -> El step 118  se ha completado correctamente en 00h00m02s ( 82 restantes )
#  -> El step 119  se ha completado correctamente en 00h00m01s ( 81 restantes )
#  -> El step 120  se ha completado correctamente en 00h00m01s ( 80 restantes )
#  -> El step 121  se ha completado correctamente en 00h00m01s ( 79 restantes )
#  -> El step 122  se ha completado correctamente en 00h00m01s ( 78 restantes )
#  -> El step 123  se ha completado correctamente en 00h00m01s ( 77 restantes )
#  -> El step 124  se ha completado correctamente en 00h00m02s ( 76 restantes )
#  -> El step 125  se ha completado correctamente en 00h00m01s ( 75 restantes )
#  -> El step 126  se ha completado correctamente en 00h00m01s ( 74 restantes )
#  -> El step 127  se ha completado correctamente en 00h00m01s ( 73 restantes )
#  -> El step 128  se ha completado correctamente en 00h00m01s ( 72 restantes )
#  -> El step 129  se ha completado correctamente en 00h00m02s ( 71 restantes )
#  -> El step 130  se ha completado correctamente en 00h00m02s ( 70 restantes )
#  -> El step 131  se ha completado correctamente en 00h00m01s ( 69 restantes )
#  -> El step 132  se ha completado correctamente en 00h00m01s ( 68 restantes )
#  -> El step 133  se ha completado correctamente en 00h00m01s ( 67 restantes )
#  -> El step 134  se ha completado correctamente en 00h00m01s ( 66 restantes )
#  -> El step 135  se ha completado correctamente en 00h00m01s ( 65 restantes )
#  -> El step 136  se ha completado correctamente en 00h00m01s ( 64 restantes )
#  -> El step 137  se ha completado correctamente en 00h00m01s ( 63 restantes )
#  -> El step 138  se ha completado correctamente en 00h00m01s ( 62 restantes )
#  -> El step 139  se ha completado correctamente en 00h00m01s ( 61 restantes )
#  -> El step 140  se ha completado correctamente en 00h00m01s ( 60 restantes )
#  -> El step 141  se ha completado correctamente en 00h00m01s ( 59 restantes )
#  -> El step 142  se ha completado correctamente en 00h00m01s ( 58 restantes )
#  -> El step 143  se ha completado correctamente en 00h00m01s ( 57 restantes )
#  -> El step 144  se ha completado correctamente en 00h00m01s ( 56 restantes )
#  -> El step 145  se ha completado correctamente en 00h00m02s ( 55 restantes )
#  -> El step 146  se ha completado correctamente en 00h00m01s ( 54 restantes )
#  -> El step 147  se ha completado correctamente en 00h00m01s ( 53 restantes )
#  -> El step 148  se ha completado correctamente en 00h00m01s ( 52 restantes )
#  -> El step 149  se ha completado correctamente en 00h00m01s ( 51 restantes )
#  -> El step 150  se ha completado correctamente en 00h00m01s ( 50 restantes )
#  -> El step 151  se ha completado correctamente en 00h00m01s ( 49 restantes )
#  -> El step 152  se ha completado correctamente en 00h00m01s ( 48 restantes )
#  -> El step 153  se ha completado correctamente en 00h00m01s ( 47 restantes )
#  -> El step 154  se ha completado correctamente en 00h00m01s ( 46 restantes )
#  -> El step 155  se ha completado correctamente en 00h00m01s ( 45 restantes )
#  -> El step 156  se ha completado correctamente en 00h00m01s ( 44 restantes )
#  -> El step 157  se ha completado correctamente en 00h00m01s ( 43 restantes )
#  -> El step 158  se ha completado correctamente en 00h00m01s ( 42 restantes )
#  -> El step 159  se ha completado correctamente en 00h00m01s ( 41 restantes )
#  -> El step 160  se ha completado correctamente en 00h00m01s ( 40 restantes )
#  -> El step 161  se ha completado correctamente en 00h00m01s ( 39 restantes )
#  -> El step 162  se ha completado correctamente en 00h00m02s ( 38 restantes )
#  -> El step 163  se ha completado correctamente en 00h00m01s ( 37 restantes )
#  -> El step 164  se ha completado correctamente en 00h00m01s ( 36 restantes )
#  -> El step 165  se ha completado correctamente en 00h00m01s ( 35 restantes )
#  -> El step 166  se ha completado correctamente en 00h00m01s ( 34 restantes )
#  -> El step 167  se ha completado correctamente en 00h00m02s ( 33 restantes )
#  -> El step 168  se ha completado correctamente en 00h00m01s ( 32 restantes )
#  -> El step 169  se ha completado correctamente en 00h00m01s ( 31 restantes )
#  -> El step 170  se ha completado correctamente en 00h00m01s ( 30 restantes )
#  -> El step 171  se ha completado correctamente en 00h00m01s ( 29 restantes )
#  -> El step 172  se ha completado correctamente en 00h00m01s ( 28 restantes )
#  -> El step 173  se ha completado correctamente en 00h00m01s ( 27 restantes )
#  -> El step 174  se ha completado correctamente en 00h00m01s ( 26 restantes )
#  -> El step 175  se ha completado correctamente en 00h00m01s ( 25 restantes )
#  -> El step 176  se ha completado correctamente en 00h00m01s ( 24 restantes )
#  -> El step 177  se ha completado correctamente en 00h00m01s ( 23 restantes )
#  -> El step 178  se ha completado correctamente en 00h00m01s ( 22 restantes )
#  -> El step 179  se ha completado correctamente en 00h00m02s ( 21 restantes )
#  -> El step 180  se ha completado correctamente en 00h00m01s ( 20 restantes )
#  -> El step 181  se ha completado correctamente en 00h00m01s ( 19 restantes )
#  -> El step 182  se ha completado correctamente en 00h00m02s ( 18 restantes )
#  -> El step 183  se ha completado correctamente en 00h00m01s ( 17 restantes )
#  -> El step 184  se ha completado correctamente en 00h00m01s ( 16 restantes )
#  -> El step 185  se ha completado correctamente en 00h00m01s ( 15 restantes )
#  -> El step 186  se ha completado correctamente en 00h00m01s ( 14 restantes )
#  -> El step 187  se ha completado correctamente en 00h00m01s ( 13 restantes )
#  -> El step 188  se ha completado correctamente en 00h00m01s ( 12 restantes )
#  -> El step 189  se ha completado correctamente en 00h00m01s ( 11 restantes )
#  -> El step 190  se ha completado correctamente en 00h00m01s ( 10 restantes )
#  -> El step 191  se ha completado correctamente en 00h00m01s ( 9 restantes )
#  -> El step 192  se ha completado correctamente en 00h00m01s ( 8 restantes )
#  -> El step 193  se ha completado correctamente en 00h00m02s ( 7 restantes )
#  -> El step 194  se ha completado correctamente en 00h00m01s ( 6 restantes )
#  -> El step 195  se ha completado correctamente en 00h00m01s ( 5 restantes )
#  -> El step 196  se ha completado correctamente en 00h00m01s ( 4 restantes )
#  -> El step 197  se ha completado correctamente en 00h00m01s ( 3 restantes )
#  -> El step 198  se ha completado correctamente en 00h00m01s ( 2 restantes )
#  -> El step 199  se ha completado correctamente en 00h00m01s ( 1 restantes )
#  -> El step 200  se ha completado correctamente en 00h00m02s ( 0 restantes )
#
#  Se ha completado la simulación del caso de estudio 6211285
#  El tiempo empleado han sido 00h07m14s
#
# ===========================================================================
#               COMIENZA LA SIMULACIÓN - PALANQUILLA 6211286
# ===========================================================================
#  -> El step 1  se ha completado correctamente en 00h00m02s ( 199 restantes )
#  -> El step 2  se ha completado correctamente en 00h00m01s ( 198 restantes )
#  -> El step 3  se ha completado correctamente en 00h00m01s ( 197 restantes )
#  -> El step 4  se ha completado correctamente en 00h00m01s ( 196 restantes )
#  -> El step 5  se ha completado correctamente en 00h00m02s ( 195 restantes )
#  -> El step 6  se ha completado correctamente en 00h00m01s ( 194 restantes )
#  -> El step 7  se ha completado correctamente en 00h00m01s ( 193 restantes )
#  -> El step 8  se ha completado correctamente en 00h00m01s ( 192 restantes )
#  -> El step 9  se ha completado correctamente en 00h00m01s ( 191 restantes )
#  -> El step 10  se ha completado correctamente en 00h00m01s ( 190 restantes )
#  -> El step 11  se ha completado correctamente en 00h00m02s ( 189 restantes )
#  -> El step 12  se ha completado correctamente en 00h00m01s ( 188 restantes )
#  -> El step 13  se ha completado correctamente en 00h00m01s ( 187 restantes )
#  -> El step 14  se ha completado correctamente en 00h00m01s ( 186 restantes )
#  -> El step 15  se ha completado correctamente en 00h00m01s ( 185 restantes )
#  -> El step 16  se ha completado correctamente en 00h00m01s ( 184 restantes )
#  -> El step 17  se ha completado correctamente en 00h00m01s ( 183 restantes )
#  -> El step 18  se ha completado correctamente en 00h00m02s ( 182 restantes )
#  -> El step 19  se ha completado correctamente en 00h00m02s ( 181 restantes )
#  -> El step 20  se ha completado correctamente en 00h00m01s ( 180 restantes )
#  -> El step 21  se ha completado correctamente en 00h00m01s ( 179 restantes )
#  -> El step 22  se ha completado correctamente en 00h00m01s ( 178 restantes )
#  -> El step 23  se ha completado correctamente en 00h00m02s ( 177 restantes )
#  -> El step 24  se ha completado correctamente en 00h00m01s ( 176 restantes )
#  -> El step 25  se ha completado correctamente en 00h00m01s ( 175 restantes )
#  -> El step 26  se ha completado correctamente en 00h00m01s ( 174 restantes )
#  -> El step 27  se ha completado correctamente en 00h00m02s ( 173 restantes )
#  -> El step 28  se ha completado correctamente en 00h00m01s ( 172 restantes )
#  -> El step 29  se ha completado correctamente en 00h00m01s ( 171 restantes )
#  -> El step 30  se ha completado correctamente en 00h00m01s ( 170 restantes )
#  -> El step 31  se ha completado correctamente en 00h00m01s ( 169 restantes )
#  -> El step 32  se ha completado correctamente en 00h00m01s ( 168 restantes )
#  -> El step 33  se ha completado correctamente en 00h00m01s ( 167 restantes )
#  -> El step 34  se ha completado correctamente en 00h00m01s ( 166 restantes )
#  -> El step 35  se ha completado correctamente en 00h00m01s ( 165 restantes )
#  -> El step 36  se ha completado correctamente en 00h00m01s ( 164 restantes )
#  -> El step 37  se ha completado correctamente en 00h00m01s ( 163 restantes )
#  -> El step 38  se ha completado correctamente en 00h00m02s ( 162 restantes )
#  -> El step 39  se ha completado correctamente en 00h00m01s ( 161 restantes )
#  -> El step 40  se ha completado correctamente en 00h00m02s ( 160 restantes )
#  -> El step 41  se ha completado correctamente en 00h00m01s ( 159 restantes )
#  -> El step 42  se ha completado correctamente en 00h00m01s ( 158 restantes )
#  -> El step 43  se ha completado correctamente en 00h00m01s ( 157 restantes )
#  -> El step 44  se ha completado correctamente en 00h00m01s ( 156 restantes )
#  -> El step 45  se ha completado correctamente en 00h00m01s ( 155 restantes )
#  -> El step 46  se ha completado correctamente en 00h00m01s ( 154 restantes )
#  -> El step 47  se ha completado correctamente en 00h00m01s ( 153 restantes )
#  -> El step 48  se ha completado correctamente en 00h00m02s ( 152 restantes )
#  -> El step 49  se ha completado correctamente en 00h00m02s ( 151 restantes )
#  -> El step 50  se ha completado correctamente en 00h00m01s ( 150 restantes )
#  -> El step 51  se ha completado correctamente en 00h00m02s ( 149 restantes )
#  -> El step 52  se ha completado correctamente en 00h00m01s ( 148 restantes )
#  -> El step 53  se ha completado correctamente en 00h00m01s ( 147 restantes )
#  -> El step 54  se ha completado correctamente en 00h00m01s ( 146 restantes )
#  -> El step 55  se ha completado correctamente en 00h00m01s ( 145 restantes )
#  -> El step 56  se ha completado correctamente en 00h00m01s ( 144 restantes )
#  -> El step 57  se ha completado correctamente en 00h00m01s ( 143 restantes )
#  -> El step 58  se ha completado correctamente en 00h00m02s ( 142 restantes )
#  -> El step 59  se ha completado correctamente en 00h00m02s ( 141 restantes )
#  -> El step 60  se ha completado correctamente en 00h00m02s ( 140 restantes )
#  -> El step 61  se ha completado correctamente en 00h00m01s ( 139 restantes )
#  -> El step 62  se ha completado correctamente en 00h00m01s ( 138 restantes )
#  -> El step 63  se ha completado correctamente en 00h00m01s ( 137 restantes )
#  -> El step 64  se ha completado correctamente en 00h00m01s ( 136 restantes )
#  -> El step 65  se ha completado correctamente en 00h00m01s ( 135 restantes )
#  -> El step 66  se ha completado correctamente en 00h00m01s ( 134 restantes )
#  -> El step 67  se ha completado correctamente en 00h00m01s ( 133 restantes )
#  -> El step 68  se ha completado correctamente en 00h00m01s ( 132 restantes )
#  -> El step 69  se ha completado correctamente en 00h00m01s ( 131 restantes )
#  -> El step 70  se ha completado correctamente en 00h00m02s ( 130 restantes )
#  -> El step 71  se ha completado correctamente en 00h00m01s ( 129 restantes )
#  -> El step 72  se ha completado correctamente en 00h00m01s ( 128 restantes )
#  -> El step 73  se ha completado correctamente en 00h00m01s ( 127 restantes )
#  -> El step 74  se ha completado correctamente en 00h00m01s ( 126 restantes )
#  -> El step 75  se ha completado correctamente en 00h00m01s ( 125 restantes )
#  -> El step 76  se ha completado correctamente en 00h00m01s ( 124 restantes )
#  -> El step 77  se ha completado correctamente en 00h00m01s ( 123 restantes )
#  -> El step 78  se ha completado correctamente en 00h00m01s ( 122 restantes )
#  -> El step 79  se ha completado correctamente en 00h00m01s ( 121 restantes )
#  -> El step 80  se ha completado correctamente en 00h00m02s ( 120 restantes )
#  -> El step 81  se ha completado correctamente en 00h00m01s ( 119 restantes )
#  -> El step 82  se ha completado correctamente en 00h00m02s ( 118 restantes )
#  -> El step 83  se ha completado correctamente en 00h00m01s ( 117 restantes )
#  -> El step 84  se ha completado correctamente en 00h00m01s ( 116 restantes )
#  -> El step 85  se ha completado correctamente en 00h00m01s ( 115 restantes )
#  -> El step 86  se ha completado correctamente en 00h00m01s ( 114 restantes )
#  -> El step 87  se ha completado correctamente en 00h00m01s ( 113 restantes )
#  -> El step 88  se ha completado correctamente en 00h00m01s ( 112 restantes )
#  -> El step 89  se ha completado correctamente en 00h00m01s ( 111 restantes )
#  -> El step 90  se ha completado correctamente en 00h00m01s ( 110 restantes )
#  -> El step 91  se ha completado correctamente en 00h00m01s ( 109 restantes )
#  -> El step 92  se ha completado correctamente en 00h00m01s ( 108 restantes )
#  -> El step 93  se ha completado correctamente en 00h00m01s ( 107 restantes )
#  -> El step 94  se ha completado correctamente en 00h00m01s ( 106 restantes )
#  -> El step 95  se ha completado correctamente en 00h00m01s ( 105 restantes )
#  -> El step 96  se ha completado correctamente en 00h00m01s ( 104 restantes )
#  -> El step 97  se ha completado correctamente en 00h00m01s ( 103 restantes )
#  -> El step 98  se ha completado correctamente en 00h00m01s ( 102 restantes )
#  -> El step 99  se ha completado correctamente en 00h00m01s ( 101 restantes )
#  -> El step 100  se ha completado correctamente en 00h00m01s ( 100 restantes )
#  -> El step 101  se ha completado correctamente en 00h00m01s ( 99 restantes )
#  -> El step 102  se ha completado correctamente en 00h00m01s ( 98 restantes )
#  -> El step 103  se ha completado correctamente en 00h00m01s ( 97 restantes )
#  -> El step 104  se ha completado correctamente en 00h00m01s ( 96 restantes )
#  -> El step 105  se ha completado correctamente en 00h00m01s ( 95 restantes )
#  -> El step 106  se ha completado correctamente en 00h00m01s ( 94 restantes )
#  -> El step 107  se ha completado correctamente en 00h00m01s ( 93 restantes )
#  -> El step 108  se ha completado correctamente en 00h00m01s ( 92 restantes )
#  -> El step 109  se ha completado correctamente en 00h00m01s ( 91 restantes )
#  -> El step 110  se ha completado correctamente en 00h00m01s ( 90 restantes )
#  -> El step 111  se ha completado correctamente en 00h00m01s ( 89 restantes )
#  -> El step 112  se ha completado correctamente en 00h00m01s ( 88 restantes )
#  -> El step 113  se ha completado correctamente en 00h00m01s ( 87 restantes )
#  -> El step 114  se ha completado correctamente en 00h00m01s ( 86 restantes )
#  -> El step 115  se ha completado correctamente en 00h00m01s ( 85 restantes )
#  -> El step 116  se ha completado correctamente en 00h00m01s ( 84 restantes )
#  -> El step 117  se ha completado correctamente en 00h00m01s ( 83 restantes )
#  -> El step 118  se ha completado correctamente en 00h00m01s ( 82 restantes )
#  -> El step 119  se ha completado correctamente en 00h00m01s ( 81 restantes )
#  -> El step 120  se ha completado correctamente en 00h00m01s ( 80 restantes )
#  -> El step 121  se ha completado correctamente en 00h00m01s ( 79 restantes )
#  -> El step 122  se ha completado correctamente en 00h00m01s ( 78 restantes )
#  -> El step 123  se ha completado correctamente en 00h00m01s ( 77 restantes )
#  -> El step 124  se ha completado correctamente en 00h00m01s ( 76 restantes )
#  -> El step 125  se ha completado correctamente en 00h00m01s ( 75 restantes )
#  -> El step 126  se ha completado correctamente en 00h00m01s ( 74 restantes )
#  -> El step 127  se ha completado correctamente en 00h00m02s ( 73 restantes )
#  -> El step 128  se ha completado correctamente en 00h00m01s ( 72 restantes )
#  -> El step 129  se ha completado correctamente en 00h00m02s ( 71 restantes )
#  -> El step 130  se ha completado correctamente en 00h00m01s ( 70 restantes )
#  -> El step 131  se ha completado correctamente en 00h00m01s ( 69 restantes )
#  -> El step 132  se ha completado correctamente en 00h00m01s ( 68 restantes )
#  -> El step 133  se ha completado correctamente en 00h00m01s ( 67 restantes )
#  -> El step 134  se ha completado correctamente en 00h00m01s ( 66 restantes )
#  -> El step 135  se ha completado correctamente en 00h00m01s ( 65 restantes )
#  -> El step 136  se ha completado correctamente en 00h00m01s ( 64 restantes )
#  -> El step 137  se ha completado correctamente en 00h00m01s ( 63 restantes )
#  -> El step 138  se ha completado correctamente en 00h00m01s ( 62 restantes )
#  -> El step 139  se ha completado correctamente en 00h00m01s ( 61 restantes )
#  -> El step 140  se ha completado correctamente en 00h00m01s ( 60 restantes )
#  -> El step 141  se ha completado correctamente en 00h00m01s ( 59 restantes )
#  -> El step 142  se ha completado correctamente en 00h00m01s ( 58 restantes )
#  -> El step 143  se ha completado correctamente en 00h00m01s ( 57 restantes )
#  -> El step 144  se ha completado correctamente en 00h00m01s ( 56 restantes )
#  -> El step 145  se ha completado correctamente en 00h00m01s ( 55 restantes )
#  -> El step 146  se ha completado correctamente en 00h00m01s ( 54 restantes )
#  -> El step 147  se ha completado correctamente en 00h00m01s ( 53 restantes )
#  -> El step 148  se ha completado correctamente en 00h00m01s ( 52 restantes )
#  -> El step 149  se ha completado correctamente en 00h00m01s ( 51 restantes )
#  -> El step 150  se ha completado correctamente en 00h00m01s ( 50 restantes )
#  -> El step 151  se ha completado correctamente en 00h00m01s ( 49 restantes )
#  -> El step 152  se ha completado correctamente en 00h00m01s ( 48 restantes )
#  -> El step 153  se ha completado correctamente en 00h00m01s ( 47 restantes )
#  -> El step 154  se ha completado correctamente en 00h00m01s ( 46 restantes )
#  -> El step 155  se ha completado correctamente en 00h00m01s ( 45 restantes )
#  -> El step 156  se ha completado correctamente en 00h00m01s ( 44 restantes )
#  -> El step 157  se ha completado correctamente en 00h00m01s ( 43 restantes )
#  -> El step 158  se ha completado correctamente en 00h00m01s ( 42 restantes )
#  -> El step 159  se ha completado correctamente en 00h00m01s ( 41 restantes )
#  -> El step 160  se ha completado correctamente en 00h00m01s ( 40 restantes )
#  -> El step 161  se ha completado correctamente en 00h00m01s ( 39 restantes )
#  -> El step 162  se ha completado correctamente en 00h00m01s ( 38 restantes )
#  -> El step 163  se ha completado correctamente en 00h00m01s ( 37 restantes )
#  -> El step 164  se ha completado correctamente en 00h00m01s ( 36 restantes )
#  -> El step 165  se ha completado correctamente en 00h00m01s ( 35 restantes )
#  -> El step 166  se ha completado correctamente en 00h00m02s ( 34 restantes )
#  -> El step 167  se ha completado correctamente en 00h00m01s ( 33 restantes )
#  -> El step 168  se ha completado correctamente en 00h00m01s ( 32 restantes )
#  -> El step 169  se ha completado correctamente en 00h00m01s ( 31 restantes )
#  -> El step 170  se ha completado correctamente en 00h00m01s ( 30 restantes )
#  -> El step 171  se ha completado correctamente en 00h00m01s ( 29 restantes )
#  -> El step 172  se ha completado correctamente en 00h00m01s ( 28 restantes )
#  -> El step 173  se ha completado correctamente en 00h00m01s ( 27 restantes )
#  -> El step 174  se ha completado correctamente en 00h00m01s ( 26 restantes )
#  -> El step 175  se ha completado correctamente en 00h00m01s ( 25 restantes )
#  -> El step 176  se ha completado correctamente en 00h00m01s ( 24 restantes )
#  -> El step 177  se ha completado correctamente en 00h00m01s ( 23 restantes )
#  -> El step 178  se ha completado correctamente en 00h00m01s ( 22 restantes )
#  -> El step 179  se ha completado correctamente en 00h00m01s ( 21 restantes )
#  -> El step 180  se ha completado correctamente en 00h00m01s ( 20 restantes )
#  -> El step 181  se ha completado correctamente en 00h00m01s ( 19 restantes )
#  -> El step 182  se ha completado correctamente en 00h00m01s ( 18 restantes )
#  -> El step 183  se ha completado correctamente en 00h00m01s ( 17 restantes )
#  -> El step 184  se ha completado correctamente en 00h00m01s ( 16 restantes )
#  -> El step 185  se ha completado correctamente en 00h00m01s ( 15 restantes )
#  -> El step 186  se ha completado correctamente en 00h00m01s ( 14 restantes )
#  -> El step 187  se ha completado correctamente en 00h00m01s ( 13 restantes )
#  -> El step 188  se ha completado correctamente en 00h00m01s ( 12 restantes )
#  -> El step 189  se ha completado correctamente en 00h00m01s ( 11 restantes )
#  -> El step 190  se ha completado correctamente en 00h00m01s ( 10 restantes )
#  -> El step 191  se ha completado correctamente en 00h00m01s ( 9 restantes )
#  -> El step 192  se ha completado correctamente en 00h00m01s ( 8 restantes )
#  -> El step 193  se ha completado correctamente en 00h00m01s ( 7 restantes )
#  -> El step 194  se ha completado correctamente en 00h00m01s ( 6 restantes )
#  -> El step 195  se ha completado correctamente en 00h00m01s ( 5 restantes )
#  -> El step 196  se ha completado correctamente en 00h00m01s ( 4 restantes )
#  -> El step 197  se ha completado correctamente en 00h00m01s ( 3 restantes )
#  -> El step 198  se ha completado correctamente en 00h00m01s ( 2 restantes )
#  -> El step 199  se ha completado correctamente en 00h00m01s ( 1 restantes )
#  -> El step 200  se ha completado correctamente en 00h00m01s ( 0 restantes )
#
#  Se ha completado la simulación del caso de estudio 6211286
#  El tiempo empleado han sido 00h06m58s
#
# ===========================================================================
#               COMIENZA LA SIMULACIÓN - PALANQUILLA 6211287
# ===========================================================================
#  -> El step 1  se ha completado correctamente en 00h00m01s ( 199 restantes )
#  -> El step 2  se ha completado correctamente en 00h00m02s ( 198 restantes )
#  -> El step 3  se ha completado correctamente en 00h00m01s ( 197 restantes )
#  -> El step 4  se ha completado correctamente en 00h00m01s ( 196 restantes )
#  -> El step 5  se ha completado correctamente en 00h00m02s ( 195 restantes )
#  -> El step 6  se ha completado correctamente en 00h00m01s ( 194 restantes )
#  -> El step 7  se ha completado correctamente en 00h00m01s ( 193 restantes )
#  -> El step 8  se ha completado correctamente en 00h00m01s ( 192 restantes )
#  -> El step 9  se ha completado correctamente en 00h00m01s ( 191 restantes )
#  -> El step 10  se ha completado correctamente en 00h00m01s ( 190 restantes )
#  -> El step 11  se ha completado correctamente en 00h00m01s ( 189 restantes )
#  -> El step 12  se ha completado correctamente en 00h00m01s ( 188 restantes )
#  -> El step 13  se ha completado correctamente en 00h00m01s ( 187 restantes )
#  -> El step 14  se ha completado correctamente en 00h00m01s ( 186 restantes )
#  -> El step 15  se ha completado correctamente en 00h00m01s ( 185 restantes )
#  -> El step 16  se ha completado correctamente en 00h00m01s ( 184 restantes )
#  -> El step 17  se ha completado correctamente en 00h00m01s ( 183 restantes )
#  -> El step 18  se ha completado correctamente en 00h00m01s ( 182 restantes )
#  -> El step 19  se ha completado correctamente en 00h00m01s ( 181 restantes )
#  -> El step 20  se ha completado correctamente en 00h00m01s ( 180 restantes )
#  -> El step 21  se ha completado correctamente en 00h00m01s ( 179 restantes )
#  -> El step 22  se ha completado correctamente en 00h00m01s ( 178 restantes )
#  -> El step 23  se ha completado correctamente en 00h00m01s ( 177 restantes )
#  -> El step 24  se ha completado correctamente en 00h00m01s ( 176 restantes )
#  -> El step 25  se ha completado correctamente en 00h00m01s ( 175 restantes )
#  -> El step 26  se ha completado correctamente en 00h00m01s ( 174 restantes )
#  -> El step 27  se ha completado correctamente en 00h00m01s ( 173 restantes )
#  -> El step 28  se ha completado correctamente en 00h00m01s ( 172 restantes )
#  -> El step 29  se ha completado correctamente en 00h00m01s ( 171 restantes )
#  -> El step 30  se ha completado correctamente en 00h00m01s ( 170 restantes )
#  -> El step 31  se ha completado correctamente en 00h00m01s ( 169 restantes )
#  -> El step 32  se ha completado correctamente en 00h00m01s ( 168 restantes )
#  -> El step 33  se ha completado correctamente en 00h00m01s ( 167 restantes )
#  -> El step 34  se ha completado correctamente en 00h00m01s ( 166 restantes )
#  -> El step 35  se ha completado correctamente en 00h00m01s ( 165 restantes )
#  -> El step 36  se ha completado correctamente en 00h00m01s ( 164 restantes )
#  -> El step 37  se ha completado correctamente en 00h00m01s ( 163 restantes )
#  -> El step 38  se ha completado correctamente en 00h00m01s ( 162 restantes )
#  -> El step 39  se ha completado correctamente en 00h00m02s ( 161 restantes )
#  -> El step 40  se ha completado correctamente en 00h00m01s ( 160 restantes )
#  -> El step 41  se ha completado correctamente en 00h00m01s ( 159 restantes )
#  -> El step 42  se ha completado correctamente en 00h00m01s ( 158 restantes )
#  -> El step 43  se ha completado correctamente en 00h00m01s ( 157 restantes )
#  -> El step 44  se ha completado correctamente en 00h00m01s ( 156 restantes )
#  -> El step 45  se ha completado correctamente en 00h00m01s ( 155 restantes )
#  -> El step 46  se ha completado correctamente en 00h00m01s ( 154 restantes )
#  -> El step 47  se ha completado correctamente en 00h00m01s ( 153 restantes )
#  -> El step 48  se ha completado correctamente en 00h00m01s ( 152 restantes )
#  -> El step 49  se ha completado correctamente en 00h00m01s ( 151 restantes )
#  -> El step 50  se ha completado correctamente en 00h00m01s ( 150 restantes )
#  -> El step 51  se ha completado correctamente en 00h00m01s ( 149 restantes )
#  -> El step 52  se ha completado correctamente en 00h00m01s ( 148 restantes )
#  -> El step 53  se ha completado correctamente en 00h00m01s ( 147 restantes )
#  -> El step 54  se ha completado correctamente en 00h00m01s ( 146 restantes )
#  -> El step 55  se ha completado correctamente en 00h00m02s ( 145 restantes )
#  -> El step 56  se ha completado correctamente en 00h00m01s ( 144 restantes )
#  -> El step 57  se ha completado correctamente en 00h00m01s ( 143 restantes )
#  -> El step 58  se ha completado correctamente en 00h00m01s ( 142 restantes )
#  -> El step 59  se ha completado correctamente en 00h00m01s ( 141 restantes )
#  -> El step 60  se ha completado correctamente en 00h00m01s ( 140 restantes )
#  -> El step 61  se ha completado correctamente en 00h00m01s ( 139 restantes )
#  -> El step 62  se ha completado correctamente en 00h00m01s ( 138 restantes )
#  -> El step 63  se ha completado correctamente en 00h00m01s ( 137 restantes )
#  -> El step 64  se ha completado correctamente en 00h00m01s ( 136 restantes )
#  -> El step 65  se ha completado correctamente en 00h00m02s ( 135 restantes )
#  -> El step 66  se ha completado correctamente en 00h00m01s ( 134 restantes )
#  -> El step 67  se ha completado correctamente en 00h00m01s ( 133 restantes )
#  -> El step 68  se ha completado correctamente en 00h00m01s ( 132 restantes )
#  -> El step 69  se ha completado correctamente en 00h00m01s ( 131 restantes )
#  -> El step 70  se ha completado correctamente en 00h00m01s ( 130 restantes )
#  -> El step 71  se ha completado correctamente en 00h00m01s ( 129 restantes )
#  -> El step 72  se ha completado correctamente en 00h00m01s ( 128 restantes )
#  -> El step 73  se ha completado correctamente en 00h00m01s ( 127 restantes )
#  -> El step 74  se ha completado correctamente en 00h00m01s ( 126 restantes )
#  -> El step 75  se ha completado correctamente en 00h00m01s ( 125 restantes )
#  -> El step 76  se ha completado correctamente en 00h00m01s ( 124 restantes )
#  -> El step 77  se ha completado correctamente en 00h00m01s ( 123 restantes )
#  -> El step 78  se ha completado correctamente en 00h00m01s ( 122 restantes )
#  -> El step 79  se ha completado correctamente en 00h00m01s ( 121 restantes )
#  -> El step 80  se ha completado correctamente en 00h00m01s ( 120 restantes )
#  -> El step 81  se ha completado correctamente en 00h00m01s ( 119 restantes )
#  -> El step 82  se ha completado correctamente en 00h00m01s ( 118 restantes )
#  -> El step 83  se ha completado correctamente en 00h00m01s ( 117 restantes )
#  -> El step 84  se ha completado correctamente en 00h00m01s ( 116 restantes )
#  -> El step 85  se ha completado correctamente en 00h00m01s ( 115 restantes )
#  -> El step 86  se ha completado correctamente en 00h00m01s ( 114 restantes )
#  -> El step 87  se ha completado correctamente en 00h00m01s ( 113 restantes )
#  -> El step 88  se ha completado correctamente en 00h00m01s ( 112 restantes )
#  -> El step 89  se ha completado correctamente en 00h00m01s ( 111 restantes )
#  -> El step 90  se ha completado correctamente en 00h00m01s ( 110 restantes )
#  -> El step 91  se ha completado correctamente en 00h00m01s ( 109 restantes )
#  -> El step 92  se ha completado correctamente en 00h00m02s ( 108 restantes )
#  -> El step 93  se ha completado correctamente en 00h00m01s ( 107 restantes )
#  -> El step 94  se ha completado correctamente en 00h00m01s ( 106 restantes )
#  -> El step 95  se ha completado correctamente en 00h00m01s ( 105 restantes )
#  -> El step 96  se ha completado correctamente en 00h00m01s ( 104 restantes )
#  -> El step 97  se ha completado correctamente en 00h00m01s ( 103 restantes )
#  -> El step 98  se ha completado correctamente en 00h00m01s ( 102 restantes )
#  -> El step 99  se ha completado correctamente en 00h00m01s ( 101 restantes )
#  -> El step 100  se ha completado correctamente en 00h00m01s ( 100 restantes )
#  -> El step 101  se ha completado correctamente en 00h00m01s ( 99 restantes )
#  -> El step 102  se ha completado correctamente en 00h00m01s ( 98 restantes )
#  -> El step 103  se ha completado correctamente en 00h00m01s ( 97 restantes )
#  -> El step 104  se ha completado correctamente en 00h00m01s ( 96 restantes )
#  -> El step 105  se ha completado correctamente en 00h00m01s ( 95 restantes )
#  -> El step 106  se ha completado correctamente en 00h00m01s ( 94 restantes )
#  -> El step 107  se ha completado correctamente en 00h00m01s ( 93 restantes )
#  -> El step 108  se ha completado correctamente en 00h00m01s ( 92 restantes )
#  -> El step 109  se ha completado correctamente en 00h00m01s ( 91 restantes )
#  -> El step 110  se ha completado correctamente en 00h00m01s ( 90 restantes )
#  -> El step 111  se ha completado correctamente en 00h00m01s ( 89 restantes )
#  -> El step 112  se ha completado correctamente en 00h00m01s ( 88 restantes )
#  -> El step 113  se ha completado correctamente en 00h00m02s ( 87 restantes )
#  -> El step 114  se ha completado correctamente en 00h00m01s ( 86 restantes )
#  -> El step 115  se ha completado correctamente en 00h00m01s ( 85 restantes )
#  -> El step 116  se ha completado correctamente en 00h00m01s ( 84 restantes )
#  -> El step 117  se ha completado correctamente en 00h00m01s ( 83 restantes )
#  -> El step 118  se ha completado correctamente en 00h00m01s ( 82 restantes )
#  -> El step 119  se ha completado correctamente en 00h00m01s ( 81 restantes )
#  -> El step 120  se ha completado correctamente en 00h00m01s ( 80 restantes )
#  -> El step 121  se ha completado correctamente en 00h00m01s ( 79 restantes )
#  -> El step 122  se ha completado correctamente en 00h00m01s ( 78 restantes )
#  -> El step 123  se ha completado correctamente en 00h00m01s ( 77 restantes )
#  -> El step 124  se ha completado correctamente en 00h00m01s ( 76 restantes )
#  -> El step 125  se ha completado correctamente en 00h00m01s ( 75 restantes )
#  -> El step 126  se ha completado correctamente en 00h00m01s ( 74 restantes )
#  -> El step 127  se ha completado correctamente en 00h00m01s ( 73 restantes )
#  -> El step 128  se ha completado correctamente en 00h00m01s ( 72 restantes )
#  -> El step 129  se ha completado correctamente en 00h00m01s ( 71 restantes )
#  -> El step 130  se ha completado correctamente en 00h00m01s ( 70 restantes )
#  -> El step 131  se ha completado correctamente en 00h00m01s ( 69 restantes )
#  -> El step 132  se ha completado correctamente en 00h00m01s ( 68 restantes )
#  -> El step 133  se ha completado correctamente en 00h00m01s ( 67 restantes )
#  -> El step 134  se ha completado correctamente en 00h00m01s ( 66 restantes )
#  -> El step 135  se ha completado correctamente en 00h00m01s ( 65 restantes )
#  -> El step 136  se ha completado correctamente en 00h00m01s ( 64 restantes )
#  -> El step 137  se ha completado correctamente en 00h00m01s ( 63 restantes )
#  -> El step 138  se ha completado correctamente en 00h00m01s ( 62 restantes )
#  -> El step 139  se ha completado correctamente en 00h00m01s ( 61 restantes )
#  -> El step 140  se ha completado correctamente en 00h00m01s ( 60 restantes )
#  -> El step 141  se ha completado correctamente en 00h00m01s ( 59 restantes )
#  -> El step 142  se ha completado correctamente en 00h00m01s ( 58 restantes )
#  -> El step 143  se ha completado correctamente en 00h00m01s ( 57 restantes )
#  -> El step 144  se ha completado correctamente en 00h00m01s ( 56 restantes )
#  -> El step 145  se ha completado correctamente en 00h00m01s ( 55 restantes )
#  -> El step 146  se ha completado correctamente en 00h00m01s ( 54 restantes )
#  -> El step 147  se ha completado correctamente en 00h00m01s ( 53 restantes )
#  -> El step 148  se ha completado correctamente en 00h00m01s ( 52 restantes )
#  -> El step 149  se ha completado correctamente en 00h00m01s ( 51 restantes )
#  -> El step 150  se ha completado correctamente en 00h00m01s ( 50 restantes )
#  -> El step 151  se ha completado correctamente en 00h00m03s ( 49 restantes )
#  -> El step 152  se ha completado correctamente en 00h00m02s ( 48 restantes )
#  -> El step 153  se ha completado correctamente en 00h00m01s ( 47 restantes )
#  -> El step 154  se ha completado correctamente en 00h00m01s ( 46 restantes )
#  -> El step 155  se ha completado correctamente en 00h00m01s ( 45 restantes )
#  -> El step 156  se ha completado correctamente en 00h00m01s ( 44 restantes )
#  -> El step 157  se ha completado correctamente en 00h00m01s ( 43 restantes )
#  -> El step 158  se ha completado correctamente en 00h00m01s ( 42 restantes )
#  -> El step 159  se ha completado correctamente en 00h00m01s ( 41 restantes )
#  -> El step 160  se ha completado correctamente en 00h00m01s ( 40 restantes )
#  -> El step 161  se ha completado correctamente en 00h00m01s ( 39 restantes )
#  -> El step 162  se ha completado correctamente en 00h00m01s ( 38 restantes )
#  -> El step 163  se ha completado correctamente en 00h00m01s ( 37 restantes )
#  -> El step 164  se ha completado correctamente en 00h00m01s ( 36 restantes )
#  -> El step 165  se ha completado correctamente en 00h00m01s ( 35 restantes )
#  -> El step 166  se ha completado correctamente en 00h00m01s ( 34 restantes )
#  -> El step 167  se ha completado correctamente en 00h00m01s ( 33 restantes )
#  -> El step 168  se ha completado correctamente en 00h00m01s ( 32 restantes )
#  -> El step 169  se ha completado correctamente en 00h00m01s ( 31 restantes )
#  -> El step 170  se ha completado correctamente en 00h00m01s ( 30 restantes )
#  -> El step 171  se ha completado correctamente en 00h00m01s ( 29 restantes )
#  -> El step 172  se ha completado correctamente en 00h00m01s ( 28 restantes )
#  -> El step 173  se ha completado correctamente en 00h00m01s ( 27 restantes )
#  -> El step 174  se ha completado correctamente en 00h00m01s ( 26 restantes )
#  -> El step 175  se ha completado correctamente en 00h00m01s ( 25 restantes )
#  -> El step 176  se ha completado correctamente en 00h00m01s ( 24 restantes )
#  -> El step 177  se ha completado correctamente en 00h00m01s ( 23 restantes )
#  -> El step 178  se ha completado correctamente en 00h00m01s ( 22 restantes )
#  -> El step 179  se ha completado correctamente en 00h00m01s ( 21 restantes )
#  -> El step 180  se ha completado correctamente en 00h00m01s ( 20 restantes )
#  -> El step 181  se ha completado correctamente en 00h00m01s ( 19 restantes )
#  -> El step 182  se ha completado correctamente en 00h00m01s ( 18 restantes )
#  -> El step 183  se ha completado correctamente en 00h00m01s ( 17 restantes )
#  -> El step 184  se ha completado correctamente en 00h00m01s ( 16 restantes )
#  -> El step 185  se ha completado correctamente en 00h00m01s ( 15 restantes )
#  -> El step 186  se ha completado correctamente en 00h00m01s ( 14 restantes )
#  -> El step 187  se ha completado correctamente en 00h00m01s ( 13 restantes )
#  -> El step 188  se ha completado correctamente en 00h00m01s ( 12 restantes )
#  -> El step 189  se ha completado correctamente en 00h00m01s ( 11 restantes )
#  -> El step 190  se ha completado correctamente en 00h00m01s ( 10 restantes )
#  -> El step 191  se ha completado correctamente en 00h00m01s ( 9 restantes )
#  -> El step 192  se ha completado correctamente en 00h00m01s ( 8 restantes )
#  -> El step 193  se ha completado correctamente en 00h00m01s ( 7 restantes )
#  -> El step 194  se ha completado correctamente en 00h00m01s ( 6 restantes )
#  -> El step 195  se ha completado correctamente en 00h00m01s ( 5 restantes )
#  -> El step 196  se ha completado correctamente en 00h00m01s ( 4 restantes )
#  -> El step 197  se ha completado correctamente en 00h00m01s ( 3 restantes )
#  -> El step 198  se ha completado correctamente en 00h00m01s ( 2 restantes )
#  -> El step 199  se ha completado correctamente en 00h00m01s ( 1 restantes )
#  -> El step 200  se ha completado correctamente en 00h00m01s ( 0 restantes )
#
#  Se ha completado la simulación del caso de estudio 6211287
#  El tiempo empleado han sido 00h06m31s
#
# ===========================================================================
#               COMIENZA LA SIMULACIÓN - PALANQUILLA 6211288
# ===========================================================================
#  -> El step 1  se ha completado correctamente en 00h00m01s ( 199 restantes )
# ...
# ===========================================================================
#  -> El step 1  se ha completado correctamente en 00h00m02s ( 199 restantes )
#  -> El step 2  se ha completado correctamente en 00h00m01s ( 198 restantes )
#  -> El step 3  se ha completado correctamente en 00h00m02s ( 197 restantes )
#  -> El step 4  se ha completado correctamente en 00h00m01s ( 196 restantes )
#  -> El step 5  se ha completado correctamente en 00h00m01s ( 195 restantes )
#  -> El step 6  se ha completado correctamente en 00h00m02s ( 194 restantes )
#  -> El step 7  se ha completado correctamente en 00h00m02s ( 193 restantes )
#  -> El step 8  se ha completado correctamente en 00h00m01s ( 192 restantes )
#  -> El step 9  se ha completado correctamente en 00h00m01s ( 191 restantes )
#  -> El step 10  se ha completado correctamente en 00h00m01s ( 190 restantes )
#  -> El step 11  se ha completado correctamente en 00h00m01s ( 189 restantes )
#  -> El step 12  se ha completado correctamente en 00h00m01s ( 188 restantes )
#  -> El step 13  se ha completado correctamente en 00h00m01s ( 187 restantes )
#  -> El step 14  se ha completado correctamente en 00h00m01s ( 186 restantes )
#  -> El step 15  se ha completado correctamente en 00h00m01s ( 185 restantes )
#  -> El step 16  se ha completado correctamente en 00h00m01s ( 184 restantes )
#  -> El step 17  se ha completado correctamente en 00h00m01s ( 183 restantes )
#  -> El step 18  se ha completado correctamente en 00h00m01s ( 182 restantes )
#  -> El step 19  se ha completado correctamente en 00h00m01s ( 181 restantes )
#  -> El step 20  se ha completado correctamente en 00h00m01s ( 180 restantes )
#  -> El step 21  se ha completado correctamente en 00h00m01s ( 179 restantes )
#  -> El step 22  se ha completado correctamente en 00h00m01s ( 178 restantes )
#  -> El step 23  se ha completado correctamente en 00h00m01s ( 177 restantes )
#  -> El step 24  se ha completado correctamente en 00h00m01s ( 176 restantes )
#  -> El step 25  se ha completado correctamente en 00h00m01s ( 175 restantes )
#  -> El step 26  se ha completado correctamente en 00h00m01s ( 174 restantes )
#  -> El step 27  se ha completado correctamente en 00h00m01s ( 173 restantes )
#  -> El step 28  se ha completado correctamente en 00h00m01s ( 172 restantes )
#  -> El step 29  se ha completado correctamente en 00h00m01s ( 171 restantes )
#  -> El step 30  se ha completado correctamente en 00h00m01s ( 170 restantes )
#  -> El step 31  se ha completado correctamente en 00h00m01s ( 169 restantes )
#  -> El step 32  se ha completado correctamente en 00h00m01s ( 168 restantes )
#  -> El step 33  se ha completado correctamente en 00h00m01s ( 167 restantes )
#  -> El step 34  se ha completado correctamente en 00h00m01s ( 166 restantes )
#  -> El step 35  se ha completado correctamente en 00h00m01s ( 165 restantes )
#  -> El step 36  se ha completado correctamente en 00h00m02s ( 164 restantes )
#  -> El step 37  se ha completado correctamente en 00h00m01s ( 163 restantes )
#  -> El step 38  se ha completado correctamente en 00h00m01s ( 162 restantes )
#  -> El step 39  se ha completado correctamente en 00h00m01s ( 161 restantes )
#  -> El step 40  se ha completado correctamente en 00h00m01s ( 160 restantes )
#  -> El step 41  se ha completado correctamente en 00h00m01s ( 159 restantes )
#  -> El step 42  se ha completado correctamente en 00h00m01s ( 158 restantes )
#  -> El step 43  se ha completado correctamente en 00h00m01s ( 157 restantes )
#  -> El step 44  se ha completado correctamente en 00h00m01s ( 156 restantes )
#  -> El step 45  se ha completado correctamente en 00h00m01s ( 155 restantes )
#  -> El step 46  se ha completado correctamente en 00h00m01s ( 154 restantes )
#  -> El step 47  se ha completado correctamente en 00h00m01s ( 153 restantes )
#  -> El step 48  se ha completado correctamente en 00h00m01s ( 152 restantes )
#  -> El step 49  se ha completado correctamente en 00h00m01s ( 151 restantes )
#  -> El step 50  se ha completado correctamente en 00h00m01s ( 150 restantes )
#  -> El step 51  se ha completado correctamente en 00h00m01s ( 149 restantes )
#  -> El step 52  se ha completado correctamente en 00h00m01s ( 148 restantes )
#  -> El step 53  se ha completado correctamente en 00h00m01s ( 147 restantes )
#  -> El step 54  se ha completado correctamente en 00h00m01s ( 146 restantes )
#  -> El step 55  se ha completado correctamente en 00h00m01s ( 145 restantes )
#  -> El step 56  se ha completado correctamente en 00h00m01s ( 144 restantes )
#  -> El step 57  se ha completado correctamente en 00h00m01s ( 143 restantes )
#  -> El step 58  se ha completado correctamente en 00h00m01s ( 142 restantes )
#  -> El step 59  se ha completado correctamente en 00h00m01s ( 141 restantes )
#  -> El step 60  se ha completado correctamente en 00h00m01s ( 140 restantes )
#  -> El step 61  se ha completado correctamente en 00h00m01s ( 139 restantes )
#  -> El step 62  se ha completado correctamente en 00h00m01s ( 138 restantes )
#  -> El step 63  se ha completado correctamente en 00h00m01s ( 137 restantes )
#  -> El step 64  se ha completado correctamente en 00h00m01s ( 136 restantes )
#  -> El step 65  se ha completado correctamente en 00h00m01s ( 135 restantes )
#  -> El step 66  se ha completado correctamente en 00h00m01s ( 134 restantes )
#  -> El step 67  se ha completado correctamente en 00h00m01s ( 133 restantes )
#  -> El step 68  se ha completado correctamente en 00h00m01s ( 132 restantes )
#  -> El step 69  se ha completado correctamente en 00h00m01s ( 131 restantes )
#  -> El step 70  se ha completado correctamente en 00h00m01s ( 130 restantes )
#  -> El step 71  se ha completado correctamente en 00h00m02s ( 129 restantes )
#  -> El step 72  se ha completado correctamente en 00h00m01s ( 128 restantes )
#  -> El step 73  se ha completado correctamente en 00h00m01s ( 127 restantes )
#  -> El step 74  se ha completado correctamente en 00h00m01s ( 126 restantes )
#  -> El step 75  se ha completado correctamente en 00h00m01s ( 125 restantes )
#  -> El step 76  se ha completado correctamente en 00h00m01s ( 124 restantes )
#  -> El step 77  se ha completado correctamente en 00h00m01s ( 123 restantes )
#  -> El step 78  se ha completado correctamente en 00h00m01s ( 122 restantes )
#  -> El step 79  se ha completado correctamente en 00h00m01s ( 121 restantes )
#  -> El step 80  se ha completado correctamente en 00h00m01s ( 120 restantes )
#  -> El step 81  se ha completado correctamente en 00h00m01s ( 119 restantes )
#  -> El step 82  se ha completado correctamente en 00h00m01s ( 118 restantes )
#  -> El step 83  se ha completado correctamente en 00h00m01s ( 117 restantes )
#  -> El step 84  se ha completado correctamente en 00h00m01s ( 116 restantes )
#  -> El step 85  se ha completado correctamente en 00h00m01s ( 115 restantes )
#  -> El step 86  se ha completado correctamente en 00h00m01s ( 114 restantes )
#  -> El step 87  se ha completado correctamente en 00h00m01s ( 113 restantes )
#  -> El step 88  se ha completado correctamente en 00h00m01s ( 112 restantes )
#  -> El step 89  se ha completado correctamente en 00h00m01s ( 111 restantes )
#  -> El step 90  se ha completado correctamente en 00h00m01s ( 110 restantes )
#  -> El step 91  se ha completado correctamente en 00h00m02s ( 109 restantes )
#  -> El step 92  se ha completado correctamente en 00h00m01s ( 108 restantes )
#  -> El step 93  se ha completado correctamente en 00h00m01s ( 107 restantes )
#  -> El step 94  se ha completado correctamente en 00h00m01s ( 106 restantes )
#  -> El step 95  se ha completado correctamente en 00h00m01s ( 105 restantes )
#  -> El step 96  se ha completado correctamente en 00h00m01s ( 104 restantes )
#  -> El step 97  se ha completado correctamente en 00h00m01s ( 103 restantes )
#  -> El step 98  se ha completado correctamente en 00h00m01s ( 102 restantes )
#  -> El step 99  se ha completado correctamente en 00h00m01s ( 101 restantes )
#  -> El step 100  se ha completado correctamente en 00h00m01s ( 100 restantes )
#  -> El step 101  se ha completado correctamente en 00h00m01s ( 99 restantes )
#  -> El step 102  se ha completado correctamente en 00h00m01s ( 98 restantes )
#  -> El step 103  se ha completado correctamente en 00h00m01s ( 97 restantes )
#  -> El step 104  se ha completado correctamente en 00h00m01s ( 96 restantes )
#  -> El step 105  se ha completado correctamente en 00h00m01s ( 95 restantes )
#  -> El step 106  se ha completado correctamente en 00h00m01s ( 94 restantes )
#  -> El step 107  se ha completado correctamente en 00h00m01s ( 93 restantes )
#  -> El step 108  se ha completado correctamente en 00h00m01s ( 92 restantes )
#  -> El step 109  se ha completado correctamente en 00h00m01s ( 91 restantes )
#  -> El step 110  se ha completado correctamente en 00h00m01s ( 90 restantes )
#  -> El step 111  se ha completado correctamente en 00h00m01s ( 89 restantes )
#  -> El step 112  se ha completado correctamente en 00h00m01s ( 88 restantes )
#  -> El step 113  se ha completado correctamente en 00h00m01s ( 87 restantes )
#  -> El step 114  se ha completado correctamente en 00h00m01s ( 86 restantes )
#  -> El step 115  se ha completado correctamente en 00h00m01s ( 85 restantes )
#  -> El step 116  se ha completado correctamente en 00h00m01s ( 84 restantes )
#  -> El step 117  se ha completado correctamente en 00h00m02s ( 83 restantes )
#  -> El step 118  se ha completado correctamente en 00h00m01s ( 82 restantes )
#  -> El step 119  se ha completado correctamente en 00h00m01s ( 81 restantes )
#  -> El step 120  se ha completado correctamente en 00h00m01s ( 80 restantes )
#  -> El step 121  se ha completado correctamente en 00h00m01s ( 79 restantes )
#  -> El step 122  se ha completado correctamente en 00h00m01s ( 78 restantes )
#  -> El step 123  se ha completado correctamente en 00h00m01s ( 77 restantes )
#  -> El step 124  se ha completado correctamente en 00h00m01s ( 76 restantes )
#  -> El step 125  se ha completado correctamente en 00h00m01s ( 75 restantes )
#  -> El step 126  se ha completado correctamente en 00h00m01s ( 74 restantes )
#  -> El step 127  se ha completado correctamente en 00h00m01s ( 73 restantes )
#  -> El step 128  se ha completado correctamente en 00h00m01s ( 72 restantes )
#  -> El step 129  se ha completado correctamente en 00h00m01s ( 71 restantes )
#  -> El step 130  se ha completado correctamente en 00h00m01s ( 70 restantes )
#  -> El step 131  se ha completado correctamente en 00h00m01s ( 69 restantes )
#  -> El step 132  se ha completado correctamente en 00h00m01s ( 68 restantes )
#  -> El step 133  se ha completado correctamente en 00h00m01s ( 67 restantes )
#  -> El step 134  se ha completado correctamente en 00h00m01s ( 66 restantes )
#  -> El step 135  se ha completado correctamente en 00h00m01s ( 65 restantes )
#  -> El step 136  se ha completado correctamente en 00h00m01s ( 64 restantes )
#  -> El step 137  se ha completado correctamente en 00h00m01s ( 63 restantes )
#  -> El step 138  se ha completado correctamente en 00h00m01s ( 62 restantes )
#  -> El step 139  se ha completado correctamente en 00h00m01s ( 61 restantes )
#  -> El step 140  se ha completado correctamente en 00h00m01s ( 60 restantes )
#  -> El step 141  se ha completado correctamente en 00h00m01s ( 59 restantes )
#  -> El step 142  se ha completado correctamente en 00h00m01s ( 58 restantes )
#  -> El step 143  se ha completado correctamente en 00h00m01s ( 57 restantes )
#  -> El step 144  se ha completado correctamente en 00h00m01s ( 56 restantes )
#  -> El step 145  se ha completado correctamente en 00h00m01s ( 55 restantes )
#  -> El step 146  se ha completado correctamente en 00h00m01s ( 54 restantes )
#  -> El step 147  se ha completado correctamente en 00h00m01s ( 53 restantes )
#  -> El step 148  se ha completado correctamente en 00h00m01s ( 52 restantes )
#  -> El step 149  se ha completado correctamente en 00h00m01s ( 51 restantes )
#  -> El step 150  se ha completado correctamente en 00h00m01s ( 50 restantes )
#  -> El step 151  se ha completado correctamente en 00h00m01s ( 49 restantes )
#  -> El step 152  se ha completado correctamente en 00h00m01s ( 48 restantes )
#  -> El step 153  se ha completado correctamente en 00h00m01s ( 47 restantes )
#  -> El step 154  se ha completado correctamente en 00h00m01s ( 46 restantes )
#  -> El step 155  se ha completado correctamente en 00h00m02s ( 45 restantes )
#  -> El step 156  se ha completado correctamente en 00h00m02s ( 44 restantes )
#  -> El step 157  se ha completado correctamente en 00h00m02s ( 43 restantes )
#  -> El step 158  se ha completado correctamente en 00h00m01s ( 42 restantes )
#  -> El step 159  se ha completado correctamente en 00h00m02s ( 41 restantes )
#  -> El step 160  se ha completado correctamente en 00h00m02s ( 40 restantes )
#  -> El step 161  se ha completado correctamente en 00h00m01s ( 39 restantes )
#  -> El step 162  se ha completado correctamente en 00h00m01s ( 38 restantes )
#  -> El step 163  se ha completado correctamente en 00h00m01s ( 37 restantes )
#  -> El step 164  se ha completado correctamente en 00h00m01s ( 36 restantes )
#  -> El step 165  se ha completado correctamente en 00h00m01s ( 35 restantes )
#  -> El step 166  se ha completado correctamente en 00h00m01s ( 34 restantes )
#  -> El step 167  se ha completado correctamente en 00h00m01s ( 33 restantes )
#  -> El step 168  se ha completado correctamente en 00h00m01s ( 32 restantes )
#  -> El step 169  se ha completado correctamente en 00h00m01s ( 31 restantes )
#  -> El step 170  se ha completado correctamente en 00h00m01s ( 30 restantes )
#  -> El step 171  se ha completado correctamente en 00h00m01s ( 29 restantes )
#  -> El step 172  se ha completado correctamente en 00h00m01s ( 28 restantes )
#  -> El step 173  se ha completado correctamente en 00h00m01s ( 27 restantes )
#  -> El step 174  se ha completado correctamente en 00h00m01s ( 26 restantes )
#  -> El step 175  se ha completado correctamente en 00h00m01s ( 25 restantes )
#  -> El step 176  se ha completado correctamente en 00h00m01s ( 24 restantes )
#  -> El step 177  se ha completado correctamente en 00h00m01s ( 23 restantes )
#  -> El step 178  se ha completado correctamente en 00h00m01s ( 22 restantes )
#  -> El step 179  se ha completado correctamente en 00h00m01s ( 21 restantes )
#  -> El step 180  se ha completado correctamente en 00h00m01s ( 20 restantes )
#  -> El step 181  se ha completado correctamente en 00h00m01s ( 19 restantes )
#  -> El step 182  se ha completado correctamente en 00h00m01s ( 18 restantes )
#  -> El step 183  se ha completado correctamente en 00h00m01s ( 17 restantes )
#  -> El step 184  se ha completado correctamente en 00h00m01s ( 16 restantes )
#  -> El step 185  se ha completado correctamente en 00h00m01s ( 15 restantes )
#  -> El step 186  se ha completado correctamente en 00h00m01s ( 14 restantes )
#  -> El step 187  se ha completado correctamente en 00h00m01s ( 13 restantes )
#  -> El step 188  se ha completado correctamente en 00h00m01s ( 12 restantes )
#  -> El step 189  se ha completado correctamente en 00h00m01s ( 11 restantes )
#  -> El step 190  se ha completado correctamente en 00h00m01s ( 10 restantes )
#  -> El step 191  se ha completado correctamente en 00h00m01s ( 9 restantes )
#  -> El step 192  se ha completado correctamente en 00h00m01s ( 8 restantes )
#  -> El step 193  se ha completado correctamente en 00h00m02s ( 7 restantes )
#  -> El step 194  se ha completado correctamente en 00h00m01s ( 6 restantes )
#  -> El step 195  se ha completado correctamente en 00h00m01s ( 5 restantes )
#  -> El step 196  se ha completado correctamente en 00h00m01s ( 4 restantes )
#  -> El step 197  se ha completado correctamente en 00h00m01s ( 3 restantes )
#  -> El step 198  se ha completado correctamente en 00h00m01s ( 2 restantes )
#  -> El step 199  se ha completado correctamente en 00h00m01s ( 1 restantes )
#  -> El step 200  se ha completado correctamente en 00h00m01s ( 0 restantes )
#
#  Se ha completado la simulación del caso de estudio 6211295
#  El tiempo empleado han sido 00h06m55s
#
# ===========================================================================
# El tiempo empleado para toda la simulación han sido 01h14m25s
# ===========================================================================
